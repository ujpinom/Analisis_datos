# %%
import numpy as np;import pandas as pd;import datetime
wind_stats=pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data',
                      sep="\s+",parse_dates=[[0,1,2]])
wind_stats
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %% [markdown]
# Las fechas proporcionadas no son consitentes con el mundo real. Se debe modificar dichas fechas haciendo uso del método apply()

# %%
def modificar_anio(x):
    if x.year>1989:
        anio=x.year-100
    else:
        anio=x.year
    return pd.to_datetime(datetime.date(anio,x.month,x.day))

wind_stats['Yr_Mo_Dy']=wind_stats['Yr_Mo_Dy'].apply(modificar_anio)

# %%
wind_stats.set_index('Yr_Mo_Dy',inplace=True)

# %% [markdown]
# Nos gustaría descubrir cuántos valores nulos hay por cada locación.

# %%
wind_stats.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
wind_stats.notnull().sum().sum()  ##Numero de muestras no nulas recogidas durante el periodo de vigilancia para todas las 
#locaciones.
# Out:
# 78857

# %% [markdown]
# Nos gustaría calcular la media,maximo,mínimo y la desviación éstandar de la velocidad del viento
# para cada una de las locaciones durante todo el periodo de registro.

# %%
loc_stats=pd.DataFrame()
loc_stats[['Media','Max','Min','std']]=wind_stats.aggregate(['mean','max','min','std'],axis=0).T
loc_stats
# Out:
#          Media    Max   Min       std
# RPT  12.362987  35.80  0.67  5.618413
# VAL  10.644314  33.37  0.21  5.267356
# ROS  11.660526  33.84  1.50  5.008450
# KIL   6.306468  28.46  0.00  3.605811
# SHA  10.455834  37.54  0.13  4.936125
# BIR   7.092254  26.16  0.00  3.968683
# DUB   9.797343  30.37  0.00  4.977555
# CLA   8.495053  31.08  0.00  4.499449
# MUL   8.493590  25.88  0.00  4.166872
# CLO   8.707332  28.21  0.04  4.503954
# BEL  13.121007  42.38  0.13  5.835037
# MAL  15.599079  42.54  0.67  6.699794

# %%
wind_stats.loc[wind_stats.index.month==1].mean()  ##Media de los vientos registrados  en los meses de enero para todas las locaciones
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
wind_stats.resample('Y').mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %%
#Alternativamente
wind_stats.groupby(wind_stats.index.to_period('A')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966      13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967      12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968      11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969      11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970      12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971      11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# 1972      12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# ...

# %%
###Agrupar por meses
wind_stats.resample('M').mean()
wind_stats.groupby(wind_stats.index.to_period('m')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03   10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10    9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11   16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12   16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
wind_stats.resample('W').aggregate(['mean','max','min','std']).iloc[0:52,:].head(10)
# Out:
#                   RPT                                VAL                \
#                  mean    max    min       std       mean    max    min
# Yr_Mo_Dy
# 1961-01-01  15.040000  15.04  15.04       NaN  14.960000  14.96  14.96
# 1961-01-08  13.541429  18.50  10.58  2.631321  11.486667  16.88   6.63
# 1961-01-15  12.468571  19.75   9.04  3.555392   8.967143  12.08   3.54
# 1961-01-22  13.204286  19.83   4.92  5.337402   9.862857  14.37   3.42
# 1961-01-29  19.880000  25.04  13.62  4.619061  16.141429  23.91   9.96
# 1961-02-05  16.827143  24.21  10.58  5.251408  15.460000  24.21   9.46
# 1961-02-12  19.684286  24.54  16.00  3.587677  16.417143  21.42  11.54
# 1961-02-19  15.130000  22.50   6.04  5.064609  15.091429  20.17  11.63
# 1961-02-26  15.221429  25.80   7.79  7.020716  13.625714  21.50   7.08
# 1961-03-05  12.101429  13.33  10.96  0.997721  12.951429  17.00   8.83
#
#                             ROS         ...    CLO                  BEL  \
# ...
